# %%
suppressPackageStartupMessages({
    library(ComplexHeatmap)
    library(circlize)
    library(dplyr)
    library(stringr)
    library(pheatmap)
})
o<- function(w,h) options(repr.plot.width=w, repr.plot.height=h)
load(url("https://gitee.com/chansigit/SSAT/raw/master/mm.tf.rda")) #load mm.tf
mm.tf <- c(mm.tf, "Bcl11b")
# Out:
# Warning message:
# “package ‘stringr’ was built under R version 4.1.3”

# %%
save_pheatmap_pdf <- function(x, filename, width=7, height=7) {
   stopifnot(!missing(x))
   stopifnot(!missing(filename))
   pdf(filename, width=width, height=height)
   grid::grid.newpage()
   grid::grid.draw(x$gtable)
   dev.off()
}

# %%
'Eomes' %in% mm.tf
# Out:
# [1] TRUE

# %%
path='./ABM-time_series.csv'
expr_z = read.csv(path,row.names = 1) %>% t %>% scale %>% t
colnames(expr_z) <- 1:ncol(expr_z)

module_info = read.csv('./module_info-ABM.csv', row.names = 1)

# %% [markdown]
# # Gata3 module

# %%
# set gene seed
geneSeed="Gata3"

# get module members
(module_info %>% filter(str_detect(member,geneSeed))%>% select(member))[1,]%>% 
str_replace_all(c('\''='', "\\["="", "\\]"="","\n"="")) %>% 
strsplit(' ') %>% unlist -> goi

# build module expression matrix
df = expr_z[goi, ]
isTFann=  data.frame(isTF=factor(ifelse(rownames(df) %in% mm.tf, "yes","no"))) 
rownames(isTFann) <- rownames(df)
isTFcolor= list(isTF = c("yes" = "red", "no" = "white"))

# draw heatmap
o(5,6)
p=pheatmap(expr_z[goi, ], cluster_cols = F, border_color=NA, show_colnames =F,
        breaks=seq(-2, 2, length.out = 101), main=paste(geneSeed, '-Id2-Tox module in ABM', sep=''),
        annotation_row=isTFann, annotation_colors=isTFcolor)

save_pheatmap_pdf(p, "output/Gata3-Id2-Tox_module-ABM.pdf", width=5, height=6)
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Rorc module

# %%
# set gene seed
geneSeed="Rorc"

# get module members
(module_info %>% filter(str_detect(member,geneSeed))%>% select(member))[1,]%>% 
str_replace_all(c('\''='', "\\["="", "\\]"="","\n"="")) %>% 
strsplit(' ') %>% unlist -> goi

# build module expression matrix
df = expr_z[goi, ]
isTFann=  data.frame(isTF=factor(ifelse(rownames(df) %in% mm.tf, "yes","no"))) 
rownames(isTFann) <- rownames(df)
isTFcolor= list(isTF = c("yes" = "red", "no" = "white"))

# draw heatmap
o(5,12)
p=pheatmap(expr_z[goi, ], cluster_cols = F, border_color=NA, show_colnames =F,
        breaks=seq(-2, 2, length.out = 101), main=paste(geneSeed, 'module in ABM'),
        annotation_row=isTFann, annotation_colors=isTFcolor)

save_pheatmap_pdf(p, "output/Rorc_module-ABM.pdf", width=5, height=12)
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Bcl11b module

# %%
# set gene seed
geneSeed="Bcl11b"

# get module members
(module_info %>% filter(str_detect(member,geneSeed))%>% select(member))[1,]%>% 
str_replace_all(c('\''='', "\\["="", "\\]"="","\n"="")) %>% 
strsplit(' ') %>% unlist -> goi

# build module expression matrix
df = expr_z[goi, ]
isTFann=  data.frame(isTF=factor(ifelse(rownames(df) %in% mm.tf, "yes","no"))) 
rownames(isTFann) <- rownames(df)
isTFcolor= list(isTF = c("yes" = "red", "no" = "white"))

# draw heatmap
o(5,10)
p= pheatmap(expr_z[goi, ], cluster_cols = F, border_color=NA, show_colnames =F,
        breaks=seq(-2, 2, length.out = 101), main=paste(geneSeed, 'module in ABM'),
        annotation_row=isTFann, annotation_colors=isTFcolor)

save_pheatmap_pdf(p, "output/Bcl11b_module-ABM.pdf", width=5, height=10)
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Tbx21 module

# %%
# set gene seed
geneSeed="Tbx21"

# get module members
(module_info %>% filter(str_detect(member,geneSeed))%>% select(member))[1,]%>% 
str_replace_all(c('\''='', "\\["="", "\\]"="","\n"="")) %>% 
strsplit(' ') %>% unlist -> goi

# build module expression matrix
df = expr_z[goi, ]
isTFann=  data.frame(isTF=factor(ifelse(rownames(df) %in% mm.tf, "yes","no"))) 
rownames(isTFann) <- rownames(df)
isTFcolor= list(isTF = c("yes" = "red", "no" = "white"))

# draw heatmap
o(5,4)
p=pheatmap(expr_z[goi, ], cluster_cols = F, border_color=NA, show_colnames =F,
        breaks=seq(-2, 2, length.out = 101), main=paste(geneSeed, 'module in ABM'),
        annotation_row=isTFann, annotation_colors=isTFcolor)

save_pheatmap_pdf(p, "output/Tbx21_module-ABM.pdf", width=5, height=4)
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Tox module

# %%
# set gene seed
geneSeed="Tox"

# get module members
(module_info %>% filter(str_detect(member,geneSeed))%>% select(member))
# Out:
#   member
# ...

# %% [markdown]
# # Id2 module

# %%
# set gene seed
geneSeed="Id2"

# get module members
(module_info %>% filter(str_detect(member,geneSeed))%>% select(member))
# Out:
#   member
# 1 ['Pdcd1' 'Bcl2' 'Fcer1g' 'Rxrg' 'Ddit4' 'Eef2' 'Id2' 'Dok2' 'Lpar6'\n 'Prr13' 'Hes1' 'Ctsw' 'Malat1' 'Gata3' 'Gsn' 'Tox2' 'Col9a3' 'Gnai3'\n 'Tox' 'Trbc1' 'Gimap5' 'Clec2i' 'Zbtb16' 'Rora' 'Tmsb4x']

# %% [markdown]
# # Rbpj module

# %%
# set gene seed
geneSeed="Rbpj"

# get module members
(module_info %>% filter(str_detect(member,geneSeed))%>% select(member))[1,]%>% 
str_replace_all(c('\''='', "\\["="", "\\]"="","\n"="")) %>% 
strsplit(' ') %>% unlist -> goi

# build module expression matrix
df = expr_z[goi, ]
isTFann=  data.frame(isTF=factor(ifelse(rownames(df) %in% mm.tf, "yes","no"))) 
rownames(isTFann) <- rownames(df)
isTFcolor= list(isTF = c("yes" = "red", "no" = "white"))

# draw heatmap
o(5,13)
p = pheatmap(expr_z[goi, ], cluster_cols = F, border_color=NA, show_colnames =F,
        breaks=seq(-2, 2, length.out = 101), main=paste(geneSeed, 'module in ABM'),
        annotation_row=isTFann, annotation_colors=isTFcolor)

save_pheatmap_pdf(p, "output/Rbpj_module-ABM.pdf", width=5, height=13)
# Out:
# png
#   2
# plot without title

# %%
cat(paste(goi,'\n'))
# Out:
# Clk1
#  Dusp23
#  Ppp2r5a
#  Tmem14a
#  Pdcl3
#  Ubxn4
#  Rabif
#  Cabin1
#  Rab21
#  Izumo4
#  Dctn2
#  Taok1
#  Rps6kb1
#  Stat3
#  Bptf
#  Morc2a
#  Zrsr1
#  Fbxw11
#  Mapk9
#  Hist3h2ba
#  Rara
#  Klhdc2
#  Prkch
#  Zkscan3
#  Med10
#  Mocs2
#  Basp1
#  Atp13a3
#  Mettl22
#  Cep19
#  Brd2
#  Ndst1
#  Poli
#  Paip2
#  Cxxc5
#  Eno1b
#  Ptprcap
#  Ric1
#  Celf2
#  Agpat2
#  Madd
#  Chd6
#  Tmem127
#  Chmp4b
#  Rnf114
#  Snapin
#  Gabpb2
#  Med12l
#  Mex3a
#  Lrrc42
#  Tmem57
#  Zfp984
#  Ugcg
#  Mpv17
#  Tmem128
#  Rbpj
#  Mob1b
#  Ccng2
#  Zfp800
#  St7
#  Hilpda
#  Tbxas1
#  Gimap9
#  Asb7
#  Zfp768
#  Fbxo46
#  Rps19
#  Map1lc3b
#  Zfp26
#  Tmem30a
#  Glb1
#  Dynlt3
#  Bcor
#  Chm
#  Tmsb15b1
#  Slc25a53
#  Psmd10
