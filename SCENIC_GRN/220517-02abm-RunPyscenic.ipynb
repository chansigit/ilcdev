# %% [markdown]
# # GRN

# %%
# !docker run -it --rm \
    -v /home/csj/mywork/ilc/220517-pyscenic-grn:/scenicdata \
    aertslab/pyscenic:0.11.2 pyscenic grn \
        --num_workers 32 \
        -o /scenicdata/expr_mat.adjacencies_abm.tsv \
        /scenicdata/expr_mat_abm.tsv \
        /scenicdata/mm_mgi_tfs.txt
# Out:
# 2022-05-17 10:51:46,975 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2022-05-17 10:52:12,037 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# preparing dask client
# parsing input
# creating dask graph
# 32 partitions
# computing dask graph
# not shutting down client, client was created externally
# finished
# distributed.worker - WARNING - Heartbeat to scheduler failed
#
# 2022-05-17 11:19:31,410 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
import pandas as pd
grn = pd.read_csv('expr_mat.adjacencies_abm.tsv',sep='\t')

# %%
grn[grn['TF']=='Gata3']
# Out:
#             TF         target    importance
# 35       Gata3            Id2  9.210185e+01
# 52       Gata3           Irf8  8.698182e+01
# 261      Gata3          Mef2c  5.955541e+01
# 341      Gata3           Ighm  5.533995e+01
# 342      Gata3        Clec12a  5.531352e+01
# ...        ...            ...           ...
# 2710676  Gata3  D630029K05Rik  5.576024e-20
# 2710722  Gata3           Ank1  5.287670e-20
# 2710768  Gata3  A830008E24Rik  4.981548e-20
# 2711135  Gata3  1700007K13Rik  2.639301e-20
# 2711249  Gata3          Ptprn  1.926475e-20
#
# [6672 rows x 3 columns]

# %% [markdown]
# # CTX

# %%
! docker run -it --rm \
    -v /home/csj/mywork/ilc/220517-pyscenic-grn:/scenicdata \
    aertslab/pyscenic:0.11.2 pyscenic ctx \
        /scenicdata/expr_mat.adjacencies_abm.tsv \
        /scenicdata/mm10__refseq-r80__10kb_up_and_down_tss.mc9nr.feather        \
        /scenicdata/mm10__refseq-r80__500bp_up_and_100bp_down_tss.mc9nr.feather \
        --annotations_fname    /scenicdata/motifs-v9-nr.mgi-m0.001-o0.0.tbl \
        --expression_mtx_fname /scenicdata/expr_mat_abm.tsv  \
        --mode "dask_multiprocessing" \
        --output /scenicdata/abm_regulons_seed1.csv \
        --num_workers 32
# Out:
# 2022-05-17 15:22:18,739 - pyscenic.cli.pyscenic - INFO - Creating modules.
#
# 2022-05-17 15:22:20,583 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2022-05-17 15:22:44,849 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2022-05-17 15:22:45,670 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [False].
#
# 2022-05-17 15:23:43,171 - pyscenic.utils - INFO - Creating modules.
#
# ...

# %% [markdown]
# # AUCell

# %%
# !docker run -it --rm \
    -v /home/csj/mywork/ilc/220517-pyscenic-grn:/scenicdata \
    aertslab/pyscenic:0.11.2 pyscenic aucell \
        /scenicdata/expr_mat_abm.tsv \
        /scenicdata/abm_regulons_seed1.csv \
        -o /scenicdata/abm_auc_mtx.csv \
        --num_workers 6
# Out:
# 2022-05-17 16:20:27,658 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2022-05-17 16:20:53,341 - pyscenic.cli.pyscenic - INFO - Loading gene signatures.
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []
#
# 2022-05-17 16:21:32,698 - pyscenic.cli.pyscenic - INFO - Calculating cellular enrichment.
#
# 2022-05-17 16:21:47,050 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
import pandas as pd
regulons_abm = pd.read_csv('./abm_regulons_seed1.csv',index_col=[0,1], header=[0,1])
auc_abm = pd.read_csv('./abm_auc_mtx.csv')
auc_abm= auc_abm.set_index("Cell")

# %%
from pyscenic.binarization import binarize
bin_abm, auc_thresholds = binarize( auc_abm, num_workers=25 )

# %%
bin_abm
# Out:
#                   2010315B03Rik(+)  2610044O15Rik8(+)  Aggf1(+)  Ahr(+)  \
# Cell
# AAACCTGAGACCTTTG                 0                  0         1       0
# AAACCTGAGATGTAAC                 0                  0         1       0
# AAACCTGGTTAGGGTG                 0                  0         0       0
# AAACGGGAGCCTATGT                 0                  0         0       0
# AAACGGGAGTGTCCAT                 0                  0         0       0
# ...                            ...                ...       ...     ...
# TTTGGTTTCATGCATG                 1                  0         0       1
# TTTGGTTTCGCGCCAA                 0                  0         1       0
# TTTGTCACACATGACT                 0                  1         0       0
# TTTGTCACACCAACCG                 0                  0         0       0
# TTTGTCATCACTCCTG                 0                  0         0       0
#
#                   Ar(+)  Arid3a(+)  Arid5b(+)  Arnt(+)  Arnt2(+)  Arntl(+)  \
# Cell
# ...

# %%
auc_abm.to_csv('auc_abm.csv')
bin_abm.to_csv('bin_abm.csv')

# %% [markdown]
# # Check regulon members

# %% [markdown]
# ## Rorc (+)

# %%
selected_motifs = ['Rorc']
df_motifs_sel = regulons_abm.iloc[ [ True if x in selected_motifs else False for x in regulons_abm.index.get_level_values('TF') ] ,:]
df_motifs_sel = df_motifs_sel.sort_values([('Enrichment','NES')], ascending=False)
df_motifs_sel
# Out:
#                                                 Enrichment            \
#                                                        AUC       NES
# TF   MotifID
# Rorc hocomoco__NR1D2_MOUSE.H11MO.0.A              0.148034  3.912438
#      hocomoco__RORG_HUMAN.H11MO.0.C               0.068219  3.904211
#      hocomoco__NR1D1_HUMAN.H11MO.1.D              0.135246  3.521089
#      transfac_pro__M07955                         0.053981  3.394355
#      stark__AWNTGGGTCA                            0.079842  3.381341
#      taipale__RORA_DBD_WAWNTRGGTYAGTAGGTCA_repr   0.058301  3.098151
#
#                                                                        \
#                                                 MotifSimilarityQvalue
# TF   MotifID
# Rorc hocomoco__NR1D2_MOUSE.H11MO.0.A                         0.000032
#      hocomoco__RORG_HUMAN.H11MO.0.C                          0.000000
#      hocomoco__NR1D1_HUMAN.H11MO.1.D                         0.000017
# ...

# %%
from pyscenic.utils import load_motifs
import operator as op
from IPython.display import HTML, display

BASE_URL = "http://motifcollections.aertslab.org/v9/logos/"
COLUMN_NAME_LOGO = "MotifLogo"
COLUMN_NAME_MOTIF_ID = "MotifID"
COLUMN_NAME_TARGETS = "TargetGenes"

def display_logos(df: pd.DataFrame, top_target_genes: int = 3, base_url: str = BASE_URL):
    """
    :param df:
    :param base_url:
    """
    # Make sure the original dataframe is not altered.
    df = df.copy()
    
    # Add column with URLs to sequence logo.
    def create_url(motif_id):
        return '<img src="{}{}.png" style="max-height:124px;"></img>'.format(base_url, motif_id)
    df[("Enrichment", COLUMN_NAME_LOGO)] = list(map(create_url, df.index.get_level_values(COLUMN_NAME_MOTIF_ID)))
    
    # Truncate TargetGenes.
    def truncate(col_val):
        return sorted(col_val, key=op.itemgetter(1))[:top_target_genes]
    
    #df[("Enrichment", COLUMN_NAME_TARGETS)] = list(map(truncate, df[("Enrichment", COLUMN_NAME_TARGETS)]))
    
    MAX_COL_WIDTH = pd.get_option('display.max_colwidth')
    pd.set_option('display.max_colwidth', 200)
    display(HTML(df.head().to_html(escape=False)))
    pd.set_option('display.max_colwidth', MAX_COL_WIDTH)
    
display_logos(df_motifs_sel)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="9" halign="left">Enrichment</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>AUC</th>
#       <th>NES</th>
#       <th>MotifSimilarityQvalue</th>
#       <th>OrthologousIdentity</th>
#       <th>Annotation</th>
#       <th>Context</th>
#       <th>TargetGenes</th>
#       <th>RankAtMax</th>
#       <th>MotifLogo</th>
#     </tr>
#     <tr>
#       <th>TF</th>
#       <th>MotifID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">Rorc</th>
#       <th>hocomoco__NR1D2_MOUSE.H11MO.0.A</th>
#       <td>0.148034</td>
#       <td>3.912438</td>
#       <td>0.000032</td>
#       <td>1.000000</td>
# ...

# %%
res.keys().tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 res.keys().tolist()
#
# AttributeError: 'dict_keys' object has no attribute 'tolist'

# %%
# Out:
#       target  importance
# 0       Rora    5.387434
# 1     Pofut1    2.928190
# 2      Nr1d1    1.487392
# 3    Fam124b    1.764017
# 4     Tecpr1    0.893833
# ..       ...         ...
# 140    Lonp2    0.909596
# 141     Lpxn    5.660284
# 142  Selenot    5.757738
# 143     Fli1    7.961083
# 144   Lingo4    7.502423
#
# [145 rows x 2 columns]

# %%
targets = regulons_abm.loc['Rorc',['Enrichment']].droplevel(0, axis=1)['TargetGenes']
targets = [eval(tg) for tg in targets]
import numpy as np
res ={}
for target in targets:
    for tup in target:
        if tup[0] in res.keys():
            res[tup[0]].append( float(tup[1]))
        else:
            res[tup[0]] = [ tup[1] ]


for k,v in res.items():
    res[k] = np.mean(v) 
targets = pd.DataFrame({"target": res.keys(), "importance": res.values() })\
         .sort_values('importance',ascending=False)

targets.to_csv('220517-SCENICprediction-ABM-Targets-of-Rorc.csv')
targets
# Out:
#             target    importance
# 121         Il18r1  3.091823e+01
# 72           Smco4  1.539920e+01
# 40          Zfand6  1.463562e+01
# 41          Bcl11b  1.221512e+01
# 37          S100a4  1.211018e+01
# ..             ...           ...
# 90         Epb41l2  2.421745e-02
# 94            Cd36  2.302366e-02
# 87   1700061F12Rik  1.057470e-02
# 120           Orc4  8.839045e-05
# 70           Il23r  1.176418e-08
#
# [145 rows x 2 columns]
