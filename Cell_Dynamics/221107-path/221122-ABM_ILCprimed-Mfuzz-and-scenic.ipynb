# %%
import scanpy as sc, pandas as pd, numpy as np

# %%
idata= sc.read_h5ad('/home/csj/mywork/ilc//220913-FL_ABM-joint_comparison/full-alp.final.h5ad')

# %%
idata
# Out:
# AnnData object with n_obs × n_vars = 9508 × 31053
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'doublet', 'pANN', 'pred.immgen.finepruned', 'pred.immgen.mainpruned', 'predicted.id', 'ann0608', 'S_score', 'G2M_score', 'phase', 'batch2', 'Phase', 'batch', 'ImmGen_refine', 'batch-ann0608', 'leiden', 'leiden_R'
#     var: 'n_cells-1', 'highly_variable-1', 'means-1', 'dispersions-1', 'dispersions_norm-1', 'is_regulon_hub-1', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'ImmGen_refine_colors', 'ann0608_colors', 'batch-ann0608_colors', 'batch_colors', 'hvg', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts', 'counts_dca', 'normalized', 'normalized_alra', 'normalized_dca', 'normalized_magic', 'pyscenic_auc', 'pyscenic_bin', 'scaled', 'scaled_dca'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(idata,color='batch')

# %%
#sc.pl.umap(idata[idata.obs.batch=='FL'],color='Tcf7', layer='pyscenic_bin')
sc.pl.umap(idata[idata.obs.batch=='FL'],color='Gata3', layer='pyscenic_bin')

# %%
sc.pl.umap(idata[idata.obs.batch=='ABMaLP1'],color='Gata3', layer='pyscenic_bin')
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 sc.pl.umap(idata[idata.obs.batch=='ABMaLP1'],color='Gata3', layer='pyscenic_bin')
#
# File ~/anaconda3/envs/celltensor/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:669, in umap(adata, **kwargs)
#     610 @_wraps_plot_scatter
#     611 @_doc_params(
#     612     adata_color_etc=doc_adata_color_etc,
#    (...)
#     616 )
#     617 def umap(adata, **kwargs) -> Union[Axes, List[Axes], None]:
#     618     """\
#     619     Scatter plot in UMAP basis.
#     620
#    (...)
#     667     tl.umap
#     668     """
# --> 669     return embedding(adata, 'umap', **kwargs)
#
# ...

# %%
sel=np.nan_to_num( np.sum(idata.layers['pyscenic_bin'], axis=0)).astype(bool)
idata[:,sel]
# Out:
# /home/csj/.local/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2631: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# View of AnnData object with n_obs × n_vars = 9508 × 0
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'doublet', 'pANN', 'pred.immgen.finepruned', 'pred.immgen.mainpruned', 'predicted.id', 'ann0608', 'S_score', 'G2M_score', 'phase', 'batch2', 'Phase', 'batch', 'ImmGen_refine', 'batch-ann0608', 'leiden', 'leiden_R'
#     var: 'n_cells-1', 'highly_variable-1', 'means-1', 'dispersions-1', 'dispersions_norm-1', 'is_regulon_hub-1', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
# ...

# %%
# Out:
# array([False, False, False, ..., False, False, False])
